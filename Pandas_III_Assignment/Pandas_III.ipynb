# %% [markdown]
# # Pandas III
#
# ## Imports and extra Files

# %%
import pandas as pd
import numpy as np
import plotly.express as px

data = pd.read_csv("elections.csv", index_col = "Candidate")

# %%
# Step 1: Define the path to the folder containing all state files
data_dir = "namesbystate"

# Step 2: Read all files in the namesbystate folder
dataframes = []  # List to store DataFrames

# Generate file paths dynamically for all states (assuming standard two-letter state codes + DC)
state_codes = [
    "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA",
    "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR",
    "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"
]

# Loop through each state file and read its data
for state in state_codes:
    file_path = f"{data_dir}/{state}.TXT"
    try:
        df = pd.read_csv(file_path, header=None, names=['State', 'Gender', 'Year', 'Name', 'Count'], low_memory=False)
        dataframes.append(df)  # Store each DataFrame in a list
    except FileNotFoundError:
        print(f"Warning: {file_path} not found. Skipping...")  

# Step 3: Merge all DataFrames into a single cumulative DataFrame
all_data = pd.concat(dataframes, ignore_index=True)

# Step 4: Grouping to consolidate duplicate entries (if needed)
bn = all_data.groupby(['State', 'Year', 'Gender', 'Name'], as_index=False)['Count'].sum()

# Display the first few rows of the final DataFrame

bn.head()
# Out:
#   State  Year Gender     Name Count
# 0    AK  1910      F     Anna    10
# 1    AK  1910      F    Annie    12
# 2    AK  1910      F  Dorothy     5
# 3    AK  1910      F    Elsie     6
# 4    AK  1910      F    Helen     7

# %%
# Step 1: Define the path to the folder containing all state files
data_dir = "namesbystate"

# Step 2: Read all files in the namesbystate folder
dataframes = []  # List to store DataFrames

# Generate file paths dynamically for all states (assuming standard two-letter state codes + DC)
state_codes = [
    "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA",
    "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR",
    "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"
]

# Loop through each state file and read its data
for state in state_codes:
    file_path = f"{data_dir}/{state}.TXT"
    try:
        df = pd.read_csv(file_path, header=None, names=['State', 'Gender', 'Year', 'Name', 'Count'], low_memory=False)
        dataframes.append(df)  # Store each DataFrame in a list
    except FileNotFoundError:
        print(f"Warning: {file_path} not found. Skipping...")  

# Step 3: Merge all DataFrames into a single cumulative DataFrame
all_data = pd.concat(dataframes, ignore_index=True)

# Step 4: Grouping to consolidate duplicate entries (if needed)
bn = all_data.groupby(['State', 'Year', 'Gender', 'Name'], as_index=False)['Count'].sum()

# Display the first few rows of the final DataFrame

bn.head()
# Out:
#   State  Year Gender     Name Count
# 0    AK  1910      F     Anna    10
# 1    AK  1910      F    Annie    12
# 2    AK  1910      F  Dorothy     5
# 3    AK  1910      F    Elsie     6
# 4    AK  1910      F    Helen     7

# %%
bn.shape
# Out:
# (6504162, 5)

# %%
#slide 8

bn = bn.reset_index()

bn[["Year", "Count"]].groupby("Year").agg(sum)
# Out:
# C:\Users\anama\AppData\Local\Temp\ipykernel_4316\367491465.py:5: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   bn[["Year", "Count"]].groupby("Year").agg(sum)
#                                                   Count
# Year
# 1910                                             507148
# 1911                                             555841
# 1912                                             870057
# 1913                                            1006484
# 1914                                            1266423
# ...                                                 ...
# 2020  6362555166664657621107564386501514810106149377...
# 2021  7292156131056560166596357547663171918756101266...
# 2022  6533177107756606835756346411722995714570798838...
# 2023  3822856664792581053886222112512109553573665128...
# Year                                              Count
#
# [229 rows x 1 columns]

# %%
#slide 9
bn.groupby("Year").mean(numeric_only=True)
# Out:
#              index
# Year
# 1910  3.352794e+06
# 1911  3.399745e+06
# 1912  3.387803e+06
# 1913  3.400766e+06
# 1914  3.393333e+06
# ...            ...
# 2020  7.994655e+05
# 2021  8.059515e+05
# 2022  8.125330e+05
# 2023  8.190360e+05
# Year  5.311835e+06
#
# [229 rows x 1 columns]

# %%
bn[["Year", "Count"]].groupby("Year").agg(max)
# Out:
# C:\Users\anama\AppData\Local\Temp\ipykernel_4316\2417643904.py:1: FutureWarning: The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   bn[["Year", "Count"]].groupby("Year").agg(max)
#       Count
# Year
# 1910   2913
# 1911   3188
# 1912   4106
# 1913   4739
# 1914   5981
# ...     ...
# 2020     99
# 2021    997
# 2022    993
# 2023    997
# Year  Count
#
# [229 rows x 1 columns]

# %%
bn[["Year", "Count"]].groupby("Year").agg(min)
# Out:
# C:\Users\anama\AppData\Local\Temp\ipykernel_4316\3931081315.py:1: FutureWarning: The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   bn[["Year", "Count"]].groupby("Year").agg(min)
#       Count
# Year
# 1910      5
# 1911      5
# 1912      5
# 1913      5
# 1914      5
# ...     ...
# 2020     10
# 2021     10
# 2022     10
# 2023     10
# Year  Count
#
# [229 rows x 1 columns]

# %%
#slide 10
bn.groupby("Year")[["Count"]].agg(sum)
# Out:
# C:\Users\anama\AppData\Local\Temp\ipykernel_4316\4177039189.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   bn.groupby("Year")[["Count"]].agg(sum)
#                                                   Count
# Year
# 1910                                             507148
# 1911                                             555841
# 1912                                             870057
# 1913                                            1006484
# 1914                                            1266423
# ...                                                 ...
# 2020  6362555166664657621107564386501514810106149377...
# 2021  7292156131056560166596357547663171918756101266...
# 2022  6533177107756606835756346411722995714570798838...
# 2023  3822856664792581053886222112512109553573665128...
# Year                                              Count
#
# [229 rows x 1 columns]

# %%
bn.groupby("Year")[["Count"]].sum()

# %%
bn.groupby("Year").sum(numeric_only=True)
# Out:
#             index
# Year
# 1910  55207103912
# 1911  58570799072
# 1912  76635488123
# 1913  83873088380
# 1914  95393381991
# ...           ...
# 2020   5129370648
# 2021   5283818034
# 2022   5368405531
# 2023   5241011364
# Year      5311835
#
# [229 rows x 1 columns]

# %%
#slide 11
babies_by_year = bn.groupby("Year")[["Count"]].agg(sum)
px.line(babies_by_year, y="Count")
# Out:
# C:\Users\anama\AppData\Local\Temp\ipykernel_4316\2693278897.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   babies_by_year = bn.groupby("Year")[["Count"]].agg(sum)

# %%
# Slide 16
f_babynames = bn[bn["Gender"] == "F"].copy()  
f_babynames
# Out:
#            index State  Year Gender      Name Count
# 0              0    AK  1910      F      Anna    10
# 1              1    AK  1910      F     Annie    12
# 2              2    AK  1910      F   Dorothy     5
# 3              3    AK  1910      F     Elsie     6
# 4              4    AK  1910      F     Helen     7
# ...          ...   ...   ...    ...       ...   ...
# 6504037  6504037    WY  2023      F  Victoria     7
# 6504038  6504038    WY  2023      F    Violet    11
# 6504039  6504039    WY  2023      F    Vivian     7
# 6504040  6504040    WY  2023      F    Willow     8
# 6504041  6504041    WY  2023      F   Wrenley     5
#
# [3612034 rows x 6 columns]

# %%
f_babynames.loc[:, "Year"] = pd.to_numeric(f_babynames["Year"], errors="coerce")
f_babynames
# Out:
#            index State  Year Gender      Name Count
# 0              0    AK  1910      F      Anna    10
# 1              1    AK  1910      F     Annie    12
# 2              2    AK  1910      F   Dorothy     5
# 3              3    AK  1910      F     Elsie     6
# 4              4    AK  1910      F     Helen     7
# ...          ...   ...   ...    ...       ...   ...
# 6504037  6504037    WY  2023      F  Victoria     7
# 6504038  6504038    WY  2023      F    Violet    11
# 6504039  6504039    WY  2023      F    Vivian     7
# 6504040  6504040    WY  2023      F    Willow     8
# 6504041  6504041    WY  2023      F   Wrenley     5
#
# [3612034 rows x 6 columns]

# %%
f_babynames = f_babynames.sort_values(["Year"])
f_babynames
# Out:
#            index State  Year Gender      Name Count
# 0              0    AK  1910      F      Anna    10
# 5261953  5261953    SD  1910      F     Marie    34
# 5261954  5261954    SD  1910      F    Marion     6
# 5261955  5261955    SD  1910      F  Marjorie    17
# 5261956  5261956    SD  1910      F    Martha    13
# ...          ...   ...   ...    ...       ...   ...
# 1342780  1342780    FL  2023      F  Cordelia     8
# 1342781  1342781    FL  2023      F      Cori     7
# 1342782  1342782    FL  2023      F   Corinna     5
# 1342688  1342688    FL  2023      F     Candy     5
# 6504041  6504041    WY  2023      F   Wrenley     5
#
# [3612034 rows x 6 columns]

# %%
jenn_counts_series = f_babynames[f_babynames["Name"] == "Jennifer"]["Count"]
jenn_counts_series
# Out:
# 4160600     6
# 4162003     5
# 432861      5
# 4163376     5
# 4166093     5
#            ..
# 5090970    15
# 5260523     7
# 4879092     5
# 6392745     6
# 1343323    35
# Name: Count, Length: 3861, dtype: object

# %%
#slide 32
data.groupby("Year").filter(lambda sf: sf["%"].max() < 45)
# Out:
#                       Year                Party  Popular vote Result  \
# Candidate
# John C. Breckinridge  1860  Southern Democratic      847953.0   loss
# Abraham Lincoln       1860           Republican     1860829.0    win
# Theodore Roosevelt    1912          Progressive     4122721.0   loss
# Woodrow Wilson        1912           Democratic     6296284.0    win
# Jill Stein            2016                Green     1457226.0   loss
#
#                               %
# Candidate
# John C. Breckinridge  18.100000
# Abraham Lincoln       39.820000
# Theodore Roosevelt    27.400000
# Woodrow Wilson        41.840000
# Jill Stein             1.073699

# %%
#slide 40
elections_sorted_by_percent = data.sort_values("%", ascending=False)

# %%
elections_sorted_by_percent.groupby("Party").first()
# Out:
#                        Year  Popular vote Result           %
# Party
# Democratic             1828      642806.0    win   56.203927
# Democratic-Republican  1820      151271.0    win  100.000000
# Federalist             1796           NaN    win   53.400000
# Green                  2016     1457226.0   loss    1.073699
# Independent            1788           NaN    win  100.000000
# Liberal Republican     1872     2834125.0   loss   43.780000
# Libertarian            2020     1865724.0   loss    1.177979
# National Republican    1828      500897.0   loss   43.796073
# National Union         1864     2213868.0    win   55.020000
# Progressive            1912     4122721.0   loss   27.400000
# Republican             1920    16144093.0    win   60.320000
# Southern Democratic    1860      847953.0   loss   18.100000
# Whig                   1840     1275763.0    win   52.870000

# %%
#slide 41
elections_sorted_by_percent = data.sort_values("%", ascending=False)

# %%
elections_sorted_by_percent.groupby("Party").agg(lambda x : x.iloc[0])
# Out:
#                        Year  Popular vote Result           %
# Party
# Democratic             1828      642806.0    win   56.203927
# Democratic-Republican  1820           NaN    win  100.000000
# Federalist             1796           NaN    win   53.400000
# Green                  2016     1457226.0   loss    1.073699
# Independent            1788           NaN    win  100.000000
# Liberal Republican     1872     2834125.0   loss   43.780000
# Libertarian            2020     1865724.0   loss    1.177979
# National Republican    1828      500897.0   loss   43.796073
# National Union         1864     2213868.0    win   55.020000
# Progressive            1912     4122721.0   loss   27.400000
# Republican             1920    16144093.0    win   60.320000
# Southern Democratic    1860      847953.0   loss   18.100000
# Whig                   1840     1275763.0    win   52.870000

# %%
best_per_party = data.loc[data.groupby("Party")["%"].idxmax()]
best_per_party
# Out:
#                         Year                  Party  Popular vote Result  \
# Candidate
# Andrew Jackson          1824  Democratic-Republican      151271.0   loss
# Andrew Jackson          1828             Democratic      642806.0    win
# Andrew Jackson          1832             Democratic      702735.0    win
# James Monroe            1816  Democratic-Republican           NaN    win
# James Monroe            1820  Democratic-Republican           NaN    win
# John Adams              1788             Federalist           NaN   loss
# John Adams              1792             Federalist           NaN   loss
# John Adams              1796             Federalist           NaN    win
# John Adams              1800             Federalist           NaN   loss
# Jill Stein              2016                  Green     1457226.0   loss
# George Washington       1788            Independent           NaN    win
# George Washington       1792            Independent           NaN    win
# Horace Greeley          1872     Liberal Republican     2834125.0   loss
# Jo Jorgensen            2020            Libertarian     1865724.0   loss
# John Quincy Adams       1820            Independent           NaN   loss
# John Quincy Adams       1824  Democratic-Republican      113142.0    win
# John Quincy Adams       1828    National Republican      500897.0   loss
# Abraham Lincoln         1860             Republican     1860829.0    win
# Abraham Lincoln         1864         National Union     2213868.0    win
# Theodore Roosevelt      1904             Republican     7628461.0    win
# Theodore Roosevelt      1912            Progressive     4122721.0   loss
# Warren G. Harding       1920             Republican    16144093.0    win
# John C. Breckinridge    1860    Southern Democratic      847953.0   loss
# William Henry Harrison  1836                   Whig      739795.0   loss
# William Henry Harrison  1840                   Whig     1275763.0    win
#
#                                  %
# Candidate
# Andrew Jackson           57.210122
# Andrew Jackson           56.203927
# Andrew Jackson           54.574789
# James Monroe             80.600000
# James Monroe            100.000000
# John Adams                     NaN
# John Adams                     NaN
# John Adams               53.400000
# John Adams               38.600000
# Jill Stein                1.073699
# George Washington       100.000000
# George Washington       100.000000
# Horace Greeley           43.780000
# Jo Jorgensen              1.177979
# John Quincy Adams              NaN
# John Quincy Adams        42.789878
# John Quincy Adams        43.796073
# Abraham Lincoln          39.820000
# Abraham Lincoln          55.020000
# Theodore Roosevelt       56.420000
# Theodore Roosevelt       27.400000
# Warren G. Harding        60.320000
# John C. Breckinridge     18.100000
# William Henry Harrison   49.110000
# William Henry Harrison   52.870000

# %%
best_per_party2 = data.sort_values("%").drop_duplicates(["Party"], keep="last")
best_per_party2
# Out:
#                         Year                  Party  Popular vote Result  \
# Candidate
# Jill Stein              2016                  Green     1457226.0   loss
# Jo Jorgensen            2020            Libertarian     1865724.0   loss
# John C. Breckinridge    1860    Southern Democratic      847953.0   loss
# Theodore Roosevelt      1912            Progressive     4122721.0   loss
# Horace Greeley          1872     Liberal Republican     2834125.0   loss
# John Quincy Adams       1828    National Republican      500897.0   loss
# William Henry Harrison  1840                   Whig     1275763.0    win
# Abraham Lincoln         1864         National Union     2213868.0    win
# Andrew Jackson          1828             Democratic      642806.0    win
# Warren G. Harding       1920             Republican    16144093.0    win
# James Monroe            1820  Democratic-Republican           NaN    win
# John Adams              1792             Federalist           NaN   loss
# John Quincy Adams       1820            Independent           NaN   loss
#
#                                  %
# Candidate
# Jill Stein                1.073699
# Jo Jorgensen              1.177979
# John C. Breckinridge     18.100000
# Theodore Roosevelt       27.400000
# Horace Greeley           43.780000
# John Quincy Adams        43.796073
# William Henry Harrison   52.870000
# Abraham Lincoln          55.020000
# Andrew Jackson           56.203927
# Warren G. Harding        60.320000
# James Monroe            100.000000
# John Adams                     NaN
# John Quincy Adams              NaN

# %%
#slide 43
grouped_by_party = data.groupby("Party")

# %%
grouped_by_party.groups
# Out:
# {'Democratic': ['Andrew Jackson', 'Andrew Jackson', 'Martin Van Buren', 'Martin Van Buren', 'James K. Polk', 'Lewis Cass', 'Franklin Pierce', 'James Buchanan', 'George B. McClellan', 'Horatio Seymour', 'Samuel J. Tilden', 'Winfield S. Hancock', 'Grover Cleveland', 'Grover Cleveland', 'Grover Cleveland', 'William Jennings Bryan', 'William Jennings Bryan', 'Alton B. Parker', 'William Jennings Bryan', 'Woodrow Wilson', 'Woodrow Wilson', 'James M. Cox', 'Joseph Biden', 'Kamala Harris'], 'Democratic-Republican': ['Thomas Jefferson', 'Thomas Jefferson', 'Thomas Jefferson', 'James Madison', 'James Madison', 'James Monroe', 'James Monroe', 'Andrew Jackson', 'John Quincy Adams'], 'Federalist': ['John Adams', 'John Adams', 'John Adams', 'John Adams', 'Charles C. Pinckney', 'Charles C. Pinckney', 'DeWitt Clinton', 'Rufus King'], 'Green': ['Jill Stein', 'Howard Hawkins'], 'Independent': ['George Washington', 'George Washington', 'John Quincy Adams'], 'Liberal Republican': ['Horace Greeley'], 'Libertarian': ['Jo Jorgensen'], 'National Republican': ['John Quincy Adams'], 'National Union': ['Abraham Lincoln'], 'Progressive': ['Theodore Roosevelt'], 'Republican': ['John C. Frémont', 'Abraham Lincoln', 'Ulysses S. Grant', 'Ulysses S. Grant', 'Rutherford B. Hayes', 'James A. Garfield', 'James G. Blaine', 'Benjamin Harrison', 'Benjamin Harrison', 'William McKinley', 'William McKinley', 'Theodore Roosevelt', 'William H. Taft', 'Charles E. Hughes', 'Warren G. Harding', 'Donald Trump', 'Donald Trump'], 'Southern Democratic': ['John C. Breckinridge'], 'Whig': ['William Henry Harrison', 'William Henry Harrison', 'Henry Clay', 'Zachary Taylor', 'Winfield Scott']}

# %%
grouped_by_party.get_group("Federalist")
# Out:
#                      Year       Party  Popular vote Result     %
# Candidate
# John Adams           1788  Federalist           NaN   loss   NaN
# John Adams           1792  Federalist           NaN   loss   NaN
# John Adams           1796  Federalist           NaN    win  53.4
# John Adams           1800  Federalist           NaN   loss  38.6
# Charles C. Pinckney  1804  Federalist           NaN   loss  27.2
# Charles C. Pinckney  1808  Federalist           NaN   loss  35.3
# DeWitt Clinton       1812  Federalist           NaN   loss  47.6
# Rufus King           1816  Federalist           NaN   loss  19.4

# %%
##slide 45
bn.groupby(["Year", "Gender"])[["Count"]].agg(sum).head(6)
# Out:
# C:\Users\anama\AppData\Local\Temp\ipykernel_4316\227823750.py:2: FutureWarning:
#
# The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#               Count
# Year Gender
# 1910 F       346139
#      M       161009
# 1911 F       365780
#      M       190061
# 1912 F       494494
#      M       375563

# %%
#slide 46
babynames_pivot = bn.pivot_table(
    index = "Year",     # rows (turned into index)
    columns = "Gender",    # column values
    values = ["Count"], # field(s) to process in each group
    aggfunc = np.sum,   # group operation
)
# Out:
# C:\Users\anama\AppData\Local\Temp\ipykernel_4316\1623782341.py:2: FutureWarning:
#
# The provided callable <function sum at 0x00000235693E3240> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.

# %%
babynames_pivot.head(6)
# Out:
#          Count
# Gender       F       M  Sex
# Year
# 1910    346139  161009  NaN
# 1911    365780  190061  NaN
# 1912    494494  375563  NaN
# 1913    555112  451372  NaN
# 1914    683095  583328  NaN
# 1915    889889  764262  NaN

# %%
#slide 49
babynames_pivot = bn.pivot_table(
    index = "Year",     # rows (turned into index)
    columns = "Gender",    # column values
    values = ["Count", "Name"],
    aggfunc = np.max,   # group operation
)
# Out:
# C:\Users\anama\AppData\Local\Temp\ipykernel_4316\197594205.py:2: FutureWarning:
#
# The provided callable <function max at 0x00000235693E3920> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.

# %%
babynames_pivot.head(6)
# Out:
#        Count               Name
# Gender     F     M  Sex       F        M  Sex
# Year
# 1910    2913  1326  NaN    Zula   Zennie  NaN
# 1911    3188  1672  NaN    Zula      Zeb  NaN
# 1912    4106  3067  NaN    Zula   Zollie  NaN
# 1913    4739  3706  NaN    Zula  Zigmund  NaN
# 1914    5981  5192  NaN    Zula  Zygmunt  NaN
# 1915    7970  6443  NaN  Zulema  Zygmunt  NaN

# %%
#slide 52
babynames_2022 = bn[bn["Year"] == 2022]

# %%
babynames_2022
# Out:
#            index State  Year Gender     Name Count
# 29770      29770    AK  2022      F  Aaliyah     7
# 29771      29771    AK  2022      F  Abigail    15
# 29772      29772    AK  2022      F      Ada     7
# 29773      29773    AK  2022      F  Adalynn     9
# 29774      29774    AK  2022      F  Addison    14
# ...          ...   ...   ...    ...      ...   ...
# 6503930  6503930    WY  2022      M   Waylon    15
# 6503931  6503931    WY  2022      M   Wesley     7
# 6503932  6503932    WY  2022      M   Weston    12
# 6503933  6503933    WY  2022      M  William    20
# 6503934  6503934    WY  2022      M    Wyatt    19
#
# [89242 rows x 6 columns]

# %%
#slide 53
data["First Name"] = data["Candidate"].str.split().str[0]
data["First Name"]
# Out:
# 0     George
# 1       John
# 2     George
# 3       John
# 4       John
#        ...
# 69    Howard
# 70    Joseph
# 71        Jo
# 72    Donald
# 73    Kamala
# Name: First Name, Length: 74, dtype: object

# %%
#slide 54
merged = pd.merge(left = data, right = babynames_2022, 
                  left_on = "First Name", right_on = "Name")
merged
# Out:
#       level_0  index_x          Candidate  Year_x        Party  Popular vote  \
# 0           0        0  George Washington    1788  Independent           NaN
# 1           0        0  George Washington    1788  Independent           NaN
# 2           0        0  George Washington    1788  Independent           NaN
# 3           0        0  George Washington    1788  Independent           NaN
# 4           0        0  George Washington    1788  Independent           NaN
# ...       ...      ...                ...     ...          ...           ...
# 2687       72       72       Donald Trump    2024   Republican    77300000.0
# 2688       72       72       Donald Trump    2024   Republican    77300000.0
# 2689       72       72       Donald Trump    2024   Republican    77300000.0
# 2690       72       72       Donald Trump    2024   Republican    77300000.0
# 2691       72       72       Donald Trump    2024   Republican    77300000.0
#
#      Result      % First Name  index_y State Year_y Gender    Name Count
# 0       win  100.0     George    30024    AK   2022      M  George     7
# 1       win  100.0     George   171182    AL   2022      M  George    34
# 2       win  100.0     George   279917    AR   2022      M  George    24
# 3       win  100.0     George   405422    AZ   2022      M  George    43
# 4       win  100.0     George   936638    CO   2022      M  George    56
# ...     ...    ...        ...      ...   ...    ...    ...     ...   ...
# 2687    win   49.8     Donald  5837810    TX   2022      M  Donald    21
# 2688    win   49.8     Donald  5941636    UT   2022      M  Donald     5
# 2689    win   49.8     Donald  6099923    VA   2022      M  Donald    11
# 2690    win   49.8     Donald  6265755    WA   2022      M  Donald    10
# 2691    win   49.8     Donald  6391654    WI   2022      M  Donald     9
#
# [2692 rows x 15 columns]

# %%
merged = data.merge(right = babynames_2022, 
                  left_on = "First Name", right_on = "Name")

merged
# Out:
#       level_0  index_x          Candidate  Year_x        Party  Popular vote  \
# 0           0        0  George Washington    1788  Independent           NaN
# 1           0        0  George Washington    1788  Independent           NaN
# 2           0        0  George Washington    1788  Independent           NaN
# 3           0        0  George Washington    1788  Independent           NaN
# 4           0        0  George Washington    1788  Independent           NaN
# ...       ...      ...                ...     ...          ...           ...
# 2687       72       72       Donald Trump    2024   Republican    77300000.0
# 2688       72       72       Donald Trump    2024   Republican    77300000.0
# 2689       72       72       Donald Trump    2024   Republican    77300000.0
# 2690       72       72       Donald Trump    2024   Republican    77300000.0
# 2691       72       72       Donald Trump    2024   Republican    77300000.0
#
#      Result      % First Name  index_y State Year_y Gender    Name Count
# 0       win  100.0     George    30024    AK   2022      M  George     7
# 1       win  100.0     George   171182    AL   2022      M  George    34
# 2       win  100.0     George   279917    AR   2022      M  George    24
# 3       win  100.0     George   405422    AZ   2022      M  George    43
# 4       win  100.0     George   936638    CO   2022      M  George    56
# ...     ...    ...        ...      ...   ...    ...    ...     ...   ...
# 2687    win   49.8     Donald  5837810    TX   2022      M  Donald    21
# 2688    win   49.8     Donald  5941636    UT   2022      M  Donald     5
# 2689    win   49.8     Donald  6099923    VA   2022      M  Donald    11
# 2690    win   49.8     Donald  6265755    WA   2022      M  Donald    10
# 2691    win   49.8     Donald  6391654    WI   2022      M  Donald     9
#
# [2692 rows x 15 columns]
