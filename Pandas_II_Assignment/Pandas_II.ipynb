# %% [markdown]
# # Pandas II
#
# ## Elections

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive/Homework/Pandas_II_Assignment/')

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#Import package
import pandas as pd
import numpy as np

data = pd.read_csv("elections.csv", index_col = "Candidate")

baby = pd.read_csv("namesbystate/CA.TXT")

# %%
#Slide 7
data.iloc[[1,2,3],[0,1,2]]
# Out:
#                    Year        Party  Popular vote
# Candidate
# John Adams         1788   Federalist           NaN
# George Washington  1792  Independent           NaN
# John Adams         1792   Federalist           NaN

# %%
#Slide 8
data.iloc[[1,2,3], 0:3]
# Out:
#                    Year        Party  Popular vote
# Candidate
# John Adams         1788   Federalist           NaN
# George Washington  1792  Independent           NaN
# John Adams         1792   Federalist           NaN

# %%
# Slide 9
data.iloc[:,0:3]
# Out:
#                    Year        Party  Popular vote
# Candidate
# George Washington  1788  Independent           NaN
# John Adams         1788   Federalist           NaN
# George Washington  1792  Independent           NaN
# John Adams         1792   Federalist           NaN
# John Adams         1796   Federalist           NaN
# ...                 ...          ...           ...
# Howard Hawkins     2020        Green      405035.0
# Joseph Biden       2020   Democratic    81268924.0
# Jo Jorgensen       2020  Libertarian     1865724.0
# Donald Trump       2024   Republican    77300000.0
# Kamala Harris      2024   Democratic    75000000.0
#
# [74 rows x 3 columns]

# %%
# Slide 10
data.iloc[[1,2,3],1]
# Out:
# Candidate
# John Adams            Federalist
# George Washington    Independent
# John Adams            Federalist
# Name: Party, dtype: object

# %%
# Slide 14
data[3:7]
# Out:
#                   Year                  Party  Popular vote Result     %
# Candidate
# John Adams        1792             Federalist           NaN   loss   NaN
# John Adams        1796             Federalist           NaN    win  53.4
# Thomas Jefferson  1796  Democratic-Republican           NaN   loss  46.6
# Thomas Jefferson  1800  Democratic-Republican           NaN    win  61.4

# %%
# Slide 15
data = data.reset_index()
data[["Year","Candidate", "Result"]]
# Out:
#     Year          Candidate Result
# 0   1788  George Washington    win
# 1   1788         John Adams   loss
# 2   1792  George Washington    win
# 3   1792         John Adams   loss
# 4   1796         John Adams    win
# ..   ...                ...    ...
# 69  2020     Howard Hawkins   loss
# 70  2020       Joseph Biden    win
# 71  2020       Jo Jorgensen   loss
# 72  2024       Donald Trump    win
# 73  2024      Kamala Harris   loss
#
# [74 rows x 3 columns]

# %%
# Slide 16
data = data.reset_index()
data["Candidate"]
# Out:
# 0     George Washington
# 1            John Adams
# 2     George Washington
# 3            John Adams
# 4            John Adams
#             ...
# 69       Howard Hawkins
# 70         Joseph Biden
# 71         Jo Jorgensen
# 72         Donald Trump
# 73        Kamala Harris
# Name: Candidate, Length: 74, dtype: object

# %% [markdown]
# ## Name By State
#
# Slides 50, 51, 52

# %%
# Slide 19

babynames_first_10_rows= baby.loc[:9,:]

# %%
# Slide 20
babynames_first_10_rows[[True, False, True, False, True, False, True, False, True, False]]
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 2    CA   F  1910   Dorothy    220
# 4    CA   F  1910   Frances    134
# 6    CA   F  1910    Evelyn    126
# 8    CA   F  1910  Virginia    101

# %%
# Slide 21
babynames_first_10_rows.loc[[True, False, True, False, True, False, True, False, True, False], :]
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 2    CA   F  1910   Dorothy    220
# 4    CA   F  1910   Frances    134
# 6    CA   F  1910    Evelyn    126
# 8    CA   F  1910  Virginia    101

# %%
# Slide 22
baby["Sex"] == "F"
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 413889    False
# 413890    False
# 413891    False
# 413892    False
# 413893    False
# Name: Sex, Length: 413894, dtype: bool

# %%
# Slide 23
baby[(baby["Sex"] == "F")]
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 243185    CA   F  2023  Zeppelin      5
# 243186    CA   F  2023   Zhamira      5
# 243187    CA   F  2023      Zina      5
# 243188    CA   F  2023     Zooey      5
# 243189    CA   F  2023     Zosia      5
#
# [243190 rows x 5 columns]

# %%
# Slide 24
baby.loc[baby["Sex"] == "F"]
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 243185    CA   F  2023  Zeppelin      5
# 243186    CA   F  2023   Zhamira      5
# 243187    CA   F  2023      Zina      5
# 243188    CA   F  2023     Zooey      5
# 243189    CA   F  2023     Zosia      5
#
# [243190 rows x 5 columns]

# %%
# Slide 25
baby[(baby["Sex"] == "F") | (baby['Year']< 2000)]
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 346088    CA   M  1999     Yuuki      5
# 346089    CA   M  1999  Zakariya      5
# 346090    CA   M  1999    Zavier      5
# 346091    CA   M  1999      Zayn      5
# 346092    CA   M  1999     Zayne      5
#
# [346093 rows x 5 columns]

# %%
# Slide 27
baby[(baby['Name']=='Bella') | (baby['Name']=='Alex') | (baby['Name']=='Narges') | (baby['Name']=='Lisa')]
# Out:
#        State Sex  Year   Name  Count
# 6289      CA   F  1923  Bella      5
# 7512      CA   F  1925  Bella      8
# 12368     CA   F  1932   Lisa      5
# 14741     CA   F  1936   Lisa      8
# 17084     CA   F  1939   Lisa      5
# ...      ...  ..   ...    ...    ...
# 399773    CA   M  2019   Alex    438
# 402648    CA   M  2020   Alex    379
# 405452    CA   M  2021   Alex    334
# 408335    CA   M  2022   Alex    345
# 411228    CA   M  2023   Alex    329
#
# [321 rows x 5 columns]

# %%
# Slide 28
girl_names = ["Bella", "Alex", "Narges","Lisa"]
baby[baby["Name"].isin(girl_names)]
# Out:
#        State Sex  Year   Name  Count
# 6289      CA   F  1923  Bella      5
# 7512      CA   F  1925  Bella      8
# 12368     CA   F  1932   Lisa      5
# 14741     CA   F  1936   Lisa      8
# 17084     CA   F  1939   Lisa      5
# ...      ...  ..   ...    ...    ...
# 399773    CA   M  2019   Alex    438
# 402648    CA   M  2020   Alex    379
# 405452    CA   M  2021   Alex    334
# 408335    CA   M  2022   Alex    345
# 411228    CA   M  2023   Alex    329
#
# [321 rows x 5 columns]

# %%
# Slide 29
baby[baby["Name"].str.startswith("N")]
# Out:
#        State Sex  Year    Name  Count
# 76        CA   F  1910   Norma     23
# 83        CA   F  1910  Nellie     20
# 127       CA   F  1910    Nina     11
# 198       CA   F  1910    Nora      6
# 310       CA   F  1911  Nellie     23
# ...      ...  ..   ...     ...    ...
# 413795    CA   M  2023   Nilan      5
# 413796    CA   M  2023   Niles      5
# 413797    CA   M  2023    Nilo      5
# 413798    CA   M  2023     Nio      5
# 413799    CA   M  2023   Novah      5
#
# [12460 rows x 5 columns]

# %%
# Slide 31
baby_name_length = baby["Name"].str.len()

baby["name_lengths"] = baby_name_length
#baby
# Out:
#        State Sex  Year      Name  Count  name_lengths
# 0         CA   F  1910      Mary    295             4
# 1         CA   F  1910     Helen    239             5
# 2         CA   F  1910   Dorothy    220             7
# 3         CA   F  1910  Margaret    163             8
# 4         CA   F  1910   Frances    134             7
# ...      ...  ..   ...       ...    ...           ...
# 413889    CA   M  2023      Ziah      5             4
# 413890    CA   M  2023    Ziaire      5             6
# 413891    CA   M  2023    Zidane      5             6
# 413892    CA   M  2023      Zyan      5             4
# 413893    CA   M  2023      Zyir      5             4
#
# [413894 rows x 6 columns]

# %%
# Slide 32
baby['name_lengths'] = baby['name_lengths']-1
#baby
# Out:
#        State Sex  Year      Name  Count  name_lengths
# 0         CA   F  1910      Mary    295             3
# 1         CA   F  1910     Helen    239             4
# 2         CA   F  1910   Dorothy    220             6
# 3         CA   F  1910  Margaret    163             7
# 4         CA   F  1910   Frances    134             6
# ...      ...  ..   ...       ...    ...           ...
# 413889    CA   M  2023      Ziah      5             3
# 413890    CA   M  2023    Ziaire      5             5
# 413891    CA   M  2023    Zidane      5             5
# 413892    CA   M  2023      Zyan      5             3
# 413893    CA   M  2023      Zyir      5             3
#
# [413894 rows x 6 columns]

# %%
# Slide 33
baby = baby.rename(columns={"name_lengths":"Length"})
#baby
# Out:
#        State Sex  Year      Name  Count  Length
# 0         CA   F  1910      Mary    295       3
# 1         CA   F  1910     Helen    239       4
# 2         CA   F  1910   Dorothy    220       6
# 3         CA   F  1910  Margaret    163       7
# 4         CA   F  1910   Frances    134       6
# ...      ...  ..   ...       ...    ...     ...
# 413889    CA   M  2023      Ziah      5       3
# 413890    CA   M  2023    Ziaire      5       5
# 413891    CA   M  2023    Zidane      5       5
# 413892    CA   M  2023      Zyan      5       3
# 413893    CA   M  2023      Zyir      5       3
#
# [413894 rows x 6 columns]

# %%
# Slide 34
baby = baby.drop("Length",axis="columns")
#baby
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 413889    CA   M  2023      Ziah      5
# 413890    CA   M  2023    Ziaire      5
# 413891    CA   M  2023    Zidane      5
# 413892    CA   M  2023      Zyan      5
# 413893    CA   M  2023      Zyir      5
#
# [413894 rows x 5 columns]

# %%
# Slide 35
baby
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 413889    CA   M  2023      Ziah      5
# 413890    CA   M  2023    Ziaire      5
# 413891    CA   M  2023    Zidane      5
# 413892    CA   M  2023      Zyan      5
# 413893    CA   M  2023      Zyir      5
#
# [413894 rows x 5 columns]

# %%
# Slide 38
yash_count = baby[baby['Name']=="Yash"]["Count"]

# %%
np.mean(yash_count)
# Out:
# 17.0

# %%
np.max(yash_count)
# Out:
# 29

# %%
# Slide 40
baby.shape
# Out:
# (413894, 5)

# %%
baby.size
# Out:
# 2069470

# %%
# Slide 41
baby.describe()
# Out:
#                 Year          Count
# count  413894.000000  413894.000000
# mean     1986.314353      79.140348
# std        27.190404     292.028292
# min      1910.000000       5.000000
# 25%      1969.000000       7.000000
# 50%      1992.000000      13.000000
# 75%      2008.000000      38.000000
# max      2023.000000    8263.000000

# %%
# Slide 42
baby["Sex"].describe()
# Out:
# count     413894
# unique         2
# top            F
# freq      243190
# Name: Sex, dtype: object

# %%
# Slide 43
baby.sample()
# Out:
#        State Sex  Year     Name  Count
# 101678    CA   F  1986  Rashida      8

# %%
baby.sample(5).iloc[:,2:]
# Out:
#         Year    Name  Count
# 405127  2020  Jeremi      5
# 39250   1958    Geri     45
# 64974   1971   Buffi      5
# 365104  2007     Ali     78
# 89119   1982   Marci     42

# %%
baby[baby["Year"]==2000].sample(4,replace = True).iloc[:,2:]
# Out:
#         Year         Name  Count
# 348494  2000       Lorenz      5
# 346371  2000      Brenden    138
# 347917  2000  Josedejesus      7
# 149367  2000        Sarai    146

# %%
# Slide 44
baby["Name"].value_counts()
# Out:
# Name
# Jean         225
# Francis      223
# Jessie       219
# Guadalupe    219
# Marion       215
#             ...
# Damaso         1
# Kanwal         1
# Karrina        1
# Kazzandra      1
# Vallen         1
# Name: count, Length: 20629, dtype: int64

# %%
# Slide 45
baby["Name"].unique()
# Out:
# array(['Mary', 'Helen', 'Dorothy', ..., 'Shohei', 'Shylo', 'Vallen'],
#       dtype=object)

# %%
# Slide 46
baby["Name"].sort_values()
# Out:
# 387660      Aadan
# 369654      Aadan
# 372774      Aadan
# 401876    Aadarsh
# 388799      Aaden
#            ...
# 232190      Zyrah
# 220708      Zyrah
# 217445      Zyrah
# 197542      Zyrah
# 408216      Zyrus
# Name: Name, Length: 413894, dtype: object

# %%
# Slide 47
baby.sort_values(by="Count",ascending=False)
# Out:
#        State Sex  Year           Name  Count
# 271693    CA   M  1957        Michael   8263
# 270669    CA   M  1956        Michael   8257
# 321036    CA   M  1990        Michael   8247
# 285500    CA   M  1969        Michael   8244
# 286795    CA   M  1970        Michael   8197
# ...      ...  ..   ...            ...    ...
# 294982    CA   M  1975  Michaelangelo      5
# 294981    CA   M  1975          Micha      5
# 294980    CA   M  1975         Markus      5
# 294979    CA   M  1975   Marcoantonio      5
# 413893    CA   M  2023           Zyir      5
#
# [413894 rows x 5 columns]

# %%
# Slide 50
baby_len = baby["Name"].str.len()

# %%
baby["name_lengths"]= baby_len

# %%
baby = baby.sort_values(by="name_lengths",ascending = False)

# %%
baby.head()
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 1    CA   F  1910     Helen    239
# 2    CA   F  1910   Dorothy    220
# 3    CA   F  1910  Margaret    163
# 4    CA   F  1910   Frances    134

# %%
# Slide 51
baby.sort_values("Name",key=lambda x: x.str.len(), ascending=False).head()
# Out:
#        State Sex  Year             Name  Count
# 341130    CA   M  1997  Ryanchristopher      5
# 348093    CA   M  2000  Franciscojavier      6
# 331124    CA   M  1993  Ryanchristopher      5
# 337819    CA   M  1996  Franciscojavier      8
# 317627    CA   M  1988  Franciscojavier     10

# %%
# Slide 52
def dr_ea_count(string):
    return string.count('dr') + string.count('ea')


baby["dr_ea_count"] = baby["Name"].map(dr_ea_count)
baby = baby.sort_values(by="dr_ea_count", ascending=False)
baby.head()
# Out:
#        State Sex  Year      Name  Count  dr_ea_count
# 115965    CA   F  1990  Deandrea      5            3
# 311780    CA   M  1985  Deandrea      6            3
# 108738    CA   F  1988  Deandrea      5            3
# 131037    CA   F  1994  Leandrea      5            3
# 101982    CA   F  1986  Deandrea      6            3
